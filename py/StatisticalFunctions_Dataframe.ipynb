# %% [markdown]
# # GROUP BY n Aggregation Functions

# %%
import pandas as pd
df=pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#GROUPBy Single Group Single Column

df.groupby(['Pclass'])['Survived'].sum()
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %%
#Groupby -Multiple Columns
df.groupby(['Pclass'])[['Survived','Fare']].sum()  #min,max,mean,median
# Out:
#         Survived        Fare
# Pclass
# 1            136  18177.4125
# 2             87   3801.8417
# 3            119   6714.6951

# %%
df.groupby(['Pclass','Sex'])['Survived'].sum()
# Out:
# Pclass  Sex
# 1       female    91
#         male      45
# 2       female    70
#         male      17
# 3       female    72
#         male      47
# Name: Survived, dtype: int64

# %%
#Groupby -Multiple Columns as Columns
# Out:
#    Pclass     Sex  Survived
# 0       1  female        91
# 1       1    male        45
# 2       2  female        70
# 3       2    male        17
# 4       3  female        72
# 5       3    male        47

# %%
#Multiple Functions
df.groupby(['Pclass'])['Survived'].agg(['mean','sum','count'])
# Out:
#             mean  sum  count
# Pclass
# 1       0.629630  136    216
# 2       0.472826   87    184
# 3       0.242363  119    491

# %%
import pandas as pd

# Assuming 'df' is your DataFrame and 'Age' is one of its columns
# Define the bins for age categories
bins = 3

# Apply the cut function to bin the 'Age' column into three categories: 'young', 'middle_age', 'old'
df['age_bins'] = pd.cut(df['Age'], bins=bins, labels=('y', 'o', 'm'))
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby(['age_bins'])['Survived'].sum()
# Out:
# age_bins
# young         130
# middle_age    144
# old            16
# Name: Survived, dtype: int64

# %%
df.groupby('Pclass').count()
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked  age_bins
# Pclass
# 1         176       214       186
# 2          16       184       173
# 3          12       491       355

# %%
# Selecting only numeric columns before applying the min function
numeric_columns = df.select_dtypes(include='number').columns

# Apply the groupby and min functions on numeric columns
result = df.groupby('Pclass')[numeric_columns].min()
result
# Out:
#         PassengerId  Survived  Pclass   Age  SibSp  Parch  Fare
# Pclass
# 1                 2         0       1  0.92      0      0   0.0
# 2                10         0       2  0.67      0      0   0.0
# 3                 1         0       3  0.42      0      0   0.0

# %%
df.groupby(['Pclass'])['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %% [markdown]
# # RENAME

# %%
# First creating Dataframe from Dict of Dict

import pandas as pd

# Define the dictionary of dictionaries with more meaningful data
data = {
    'StudentID': {'101': 'John', '102': 'Alice', '103': 'Bob'},
    'Age': {'101': 21, '102': 20, '103': 22},
    'Grade': {'101': 'A', '102': 'B', '103': 'C'}
}

# Create DataFrame from the dictionary of dictionaries
df = pd.DataFrame(data)

# Print the DataFrame
print(df)
# Out:
#     StudentID  Age Grade
# 101      John   21     A
# 102     Alice   20     B
# 103       Bob   22     C

# %%
df.columns=['Rollno','Age','Grade']
df
# Out:
#     Rollno  Age Grade
# 101   John   21     A
# 102  Alice   20     B
# 103    Bob   22     C

# %% [markdown]
# # Dropping Columns

# %%
import pandas as pd
df=pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(['Parch'],axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(['Parch','Embarked'],axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = df.drop(df.columns[[2, 3]], axis=1)
df
# Out:
#      PassengerId  Survived            Ticket     Fare Cabin Embarked
# 0              1         0         A/5 21171   7.2500   NaN        S
# 1              2         1          PC 17599  71.2833   C85        C
# 2              3         1  STON/O2. 3101282   7.9250   NaN        S
# 3              4         1            113803  53.1000  C123        S
# 4              5         0            373450   8.0500   NaN        S
# ..           ...       ...               ...      ...   ...      ...
# 886          887         0            211536  13.0000   NaN        S
# 887          888         1            112053  30.0000   B42        S
# 888          889         0        W./C. 6607  23.4500   NaN        S
# 889          890         1            111369  30.0000  C148        C
# 890          891         0            370376   7.7500   NaN        Q
#
# [891 rows x 6 columns]

# %%
# Using drop() with iloc()
df.drop(df.iloc[:,2:4],axis=1)
# Out:
#      PassengerId  Survived Cabin Embarked
# 0              1         0   NaN        S
# 1              2         1   C85        C
# 2              3         1   NaN        S
# 3              4         1  C123        S
# 4              5         0   NaN        S
# ..           ...       ...   ...      ...
# 886          887         0   NaN        S
# 887          888         1   B42        S
# 888          889         0   NaN        S
# 889          890         1  C148        C
# 890          891         0   NaN        Q
#
# [891 rows x 4 columns]

# %%
df.drop(df.loc[:,'Survived':'Cabin'].columns,axis=1)
# Out:
#      PassengerId Embarked
# 0              1        S
# 1              2        C
# 2              3        S
# 3              4        S
# 4              5        S
# ..           ...      ...
# 886          887        S
# 887          888        S
# 888          889        S
# 889          890        C
# 890          891        Q
#
# [891 rows x 2 columns]

# %%
# using Del n For loop

# %% [markdown]
# # PIVOTING

# %%
# Pivot allowsyou to reshape or transform your Dataframe

# %%
import pandas as pd
df=pd.read_csv("weather.csv")
df
# Out:
#          date      city  temperature   humidity
# 0  05-01-2017  new york            65        56
# 1  05-02-2017  new york            66        58
# 2  05-03-2017  new york            68        60
# 3  05-01-2017    mumbai            75        80
# 4  05-02-2017    mumbai            78        83
# 5  05-03-2017    mumbai            83        85
# 6  05-01-2017   beijing            87        26
# 7  05-02-2017   beijing            77        30
# 8  05-03-2017   beijing            79        35

# %%
pivot_df = df.pivot(index='date', columns='city')
pivot_df
# Out:
#            temperature                  humidity
# city            beijing mumbai new york  beijing mumbai new york
# date
# 05-01-2017           87     75       65       26     80       56
# 05-02-2017           77     78       66       30     83       58
# 05-03-2017           79     83       68       35     85       60

# %%
df.pivot(index="date",columns="city",values="humidity")
# Out:
# city        beijing  mumbai  new york
# date
# 05-01-2017       26      80        56
# 05-02-2017       30      83        58
# 05-03-2017       35      85        60

# %%
df.pivot(index="humidity",columns="city")
# Out:
#                 date                         temperature
# city         beijing      mumbai    new york      beijing mumbai new york
# humidity
# 26        05-01-2017         NaN         NaN         87.0    NaN      NaN
# 30        05-02-2017         NaN         NaN         77.0    NaN      NaN
# 35        05-03-2017         NaN         NaN         79.0    NaN      NaN
# 56               NaN         NaN  05-01-2017          NaN    NaN     65.0
# 58               NaN         NaN  05-02-2017          NaN    NaN     66.0
# 60               NaN         NaN  05-03-2017          NaN    NaN     68.0
# 80               NaN  05-01-2017         NaN          NaN   75.0      NaN
# 83               NaN  05-02-2017         NaN          NaN   78.0      NaN
# 85               NaN  05-03-2017         NaN          NaN   83.0      NaN

# %%
#Pivot table is used to summarize and aggregate data inside the dataframe

# %%
import pandas as pd
df=pd.read_csv("weather2.csv")
df
# Out:
#          date     city  temperature  humidity
# 0  05-01-2017  newyork           10        10
# 1  05-01-2017  newyork           20        20
# 2  05-02-2017  newyork           30        30
# 3  05-02-2017  newyork           40        50
# 4  05-01-2017   mumbai           50        60
# 5  05-01-2017   mumbai           60        70
# 6  05-02-2017   mumbai           70        80
# 7  05-02-2017   mumbai           80        40

# %%
df.pivot_table(index="city",columns="date")
# Out:
#           humidity            temperature
# date    05-01-2017 05-02-2017  05-01-2017 05-02-2017
# city
# mumbai          65         60          55         75
# newyork         15         40          15         35

# %%
df.pivot_table(index="city",columns="date",aggfunc="count")
# Out:
#           humidity            temperature
# date    05-01-2017 05-02-2017  05-01-2017 05-02-2017
# city
# mumbai           2          2           2          2
# newyork          2          2           2          2

# %%
df.pivot_table(index="city",columns="date",aggfunc="sum")
# Out:
#           humidity            temperature
# date    05-01-2017 05-02-2017  05-01-2017 05-02-2017
# city
# mumbai         130        120         110        150
# newyork         30         80          30         70

# %%
df.pivot_table(index="city",columns="date",aggfunc="mean")
# Out:
#           humidity            temperature
# date    05-01-2017 05-02-2017  05-01-2017 05-02-2017
# city
# mumbai          65         60          55         75
# newyork         15         40          15         35

# %%
df.pivot_table(index="city",columns="date",margins=False)
# Out:
#           humidity            temperature
# date    05-01-2017 05-02-2017  05-01-2017 05-02-2017
# city
# mumbai          65         60          55         75
# newyork         15         40          15         35

# %%
import pandas as pd

# Sample DataFrame
data = {'date': ['2022-01-01', '2022-01-01', '2022-01-02', '2022-01-02'],
        'city': ['A', 'B', 'A', 'B'],
        'value': [10, 20, 30, 40]}
df = pd.DataFrame(data)

# Convert 'date' column to datetime type
df['date'] = pd.to_datetime(df['date'])

# Pivot table with sum aggregation
pivot_df = df.pivot_table(index='city', columns='date', values='value', aggfunc='sum')

print(pivot_df)
# Out:
# date  2022-01-01  2022-01-02
# city
# A             10          30
# B             20          40

# %%
import pandas as pd
df=pd.read_csv("weather3.csv")
df
# Out:
#          date      city  temperature  humidity
# 0  05-01-2017  new york           65        56
# 1  05-02-2017  new york           61        54
# 2  05-03-2017  new york           70        60
# 3  12-01-2017  new york           30        50
# 4  12-02-2017  new york           28        52
# 5  12-03-2017  new york           25        50

# %%
type(df['date'])
# Out:
# pandas.core.series.Series

# %%
df['date'] = pd.to_datetime(df['date'])

df.pivot_table(index=pd.Grouper(freq='M',key='date'),columns='city')
# Out:
#              humidity temperature
# city         new york    new york
# date
# 2017-05-31  56.666667   65.333333
# 2017-12-31  50.666667   27.666667

# %%
import pandas as pd
df=pd.DataFrame({"A":[12,4,5,44,1],
                "B":[5,2,54,3,2],
                "C":[20,16,7,3,8],
                "D":[14,3,17,2,6]})
df
# Out:
#     A   B   C   D
# 0  12   5  20  14
# 1   4   2  16   3
# 2   5  54   7  17
# 3  44   3   3   2
# 4   1   2   8   6

# %%
#min(axis=None)function
#min(axis=rows(0)[Default],columns(1))
# Out:
#   File "C:\Users\Tarunim Sharma\AppData\Local\Temp\ipykernel_10356\2147146346.py", line 1
#     min(axis=None)function
#                   ^
# SyntaxError: invalid syntax

# %%
print(df)
print(df.max())
print(df.max(axis=1))
# Out:
#     A   B   C   D
# 0  12   5  20  14
# 1   4   2  16   3
# 2   5  54   7  17
# 3  44   3   3   2
# 4   1   2   8   6
# A    44
# B    54
# C    20
# D    17
# dtype: int64
# 0    20
# 1    16
# 2    54
# 3    44
# 4     8
# dtype: int64

# %%
print(df)
print(df.min())
#print(df.min(axis=1))
# Out:
#     A   B   C   D
# 0  12   5  20  14
# 1   4   2  16   3
# 2   5  54   7  17
# 3  44   3   3   2
# 4   1   2   8   6
# A    1
# B    2
# C    3
# D    2
# dtype: int64

# %% [markdown]
# # count(axis=0,numeric_only=False)

# %%
import pandas as pd
df=pd.DataFrame({"A":[12,4,5,44,1],
                "B":[5,2,54,3,2],
                "C":[20,16,7,3,8],
                "D":[14,3,17,2,6]})
df
# Out:
#     A   B   C   D
# 0  12   5  20  14
# 1   4   2  16   3
# 2   5  54   7  17
# 3  44   3   3   2
# 4   1   2   8   6

# %%
print(df.count())
# Out:
# A    5
# B    5
# C    5
# D    5
# dtype: int64

# %%
print(df.count(axis=1))
# Out:
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4
# dtype: int64

# %% [markdown]
# # mean(axis=None)

# %%
import pandas as pd
df=pd.DataFrame({"A":[12,4,5,44,1],
                "B":[5,2,54,3,2],
                "C":[20,16,7,3,8],
                "D":[14,3,17,2,6]})
df
# Out:
#     A   B   C   D
# 0  12   5  20  14
# 1   4   2  16   3
# 2   5  54   7  17
# 3  44   3   3   2
# 4   1   2   8   6

# %%
print(df.mean())
# Out:
# A    13.2
# B    13.2
# C    10.8
# D     8.4
# dtype: float64

# %%
print(df.mean(axis='rows')) #0
# Out:
# A    13.2
# B    13.2
# C    10.8
# D     8.4
# dtype: float64

# %%
print(df.mean(axis='columns'))  #1
# Out:
# 0    12.75
# 1     6.25
# 2    20.75
# 3    13.00
# 4     4.25
# dtype: float64

# %%
print(df.median())
# Out:
# A    5.0
# B    3.0
# C    8.0
# D    6.0
# dtype: float64

# %%
print(df.median(axis='columns'))
# Out:
# 0    13.0
# 1     3.5
# 2    12.0
# 3     3.0
# 4     4.0
# dtype: float64

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'A':[1,2,3,1],
                'B':[4,1,6,4],
                'C':[7,8,2,2],
                'D':[7,8,2,2]})

print(df)
print(df.mode())
# Out:
#    A  B  C  D
# 0  1  4  7  7
# 1  2  1  8  8
# 2  3  6  2  2
# 3  1  4  2  2
#    A  B  C  D
# 0  1  4  2  2

# %%
print(df.mode(axis='columns'))
# Out:
#    0
# 0  7
# 1  8
# 2  2
# 3  2

# %% [markdown]
# # Finding Duplicates

# %%
import pandas as pd
 
# Dataset
data = {
    'student': ["Amit", "John", "Amit", "David", "Steve"],
    'rank': [1, 4, 1, 5, 3],
    'marks': [95, 70, 97, 60, 90]
}
 
df = pd.DataFrame(data)
 
print("Student Records\n\n", df)
 
# Find duplicates
res = df.duplicated()
print("\nDescribing Duplicates:\n",res)
# Out:
# Student Records
#
#    student  rank  marks
# 0    Amit     1     95
# 1    John     4     70
# 2    Amit     1     97
# 3   David     5     60
# 4   Steve     3     90
#
# Describing Duplicates:
#  0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
import pandas as pd
 
# Dataset
data = {
    'student': ["Amit", "John", "Amit", "David", "Steve"],
    'rank': [1, 4, 1, 5, 3],
    'marks': [95, 70, 95, 60, 90]
}
 
df = pd.DataFrame(data)
 
print("Student Records\n\n", df)
 
# Delete duplicates using the drop_duplicates()
res = df.drop_duplicates()
print("\nNew DataFrame after deleting duplicates:\n",res)
# Out:
# Student Records
#
#    student  rank  marks
# 0    Amit     1     95
# 1    John     4     70
# 2    Amit     1     95
# 3   David     5     60
# 4   Steve     3     90
#
# New DataFrame after deleting duplicates:
#    student  rank  marks
# 0    Amit     1     95
# 1    John     4     70
# 3   David     5     60
# 4   Steve     3     90

# %% [markdown]
# # Join Records

# %%
# Write a Pandas program to join the two given dataframes along rows and assign all data.


import pandas as pd

student_data1 = pd.DataFrame({
        'student_id': ['S1', 'S2', 'S3', 'S4', 'S5'],
         'name': ['Danniella Fenton', 'Ryder Storey', 'Bryce Jensen', 'Ed Bernal', 'Kwame Morin'], 
        'marks': [200, 210, 190, 222, 199]})

student_data2 = pd.DataFrame({
        'student_id': ['S4', 'S5', 'S6', 'S7', 'S8'],
        'name': ['Scarlette Fisher', 'Carla Williamson', 'Dante Morse', 'Kaiser William', 'Madeeha Preston'], 
        'marks': [201, 200, 198, 219, 201]})

print("Original DataFrames:")
print(student_data1)
print("-------------------------------------")
print(student_data2)
print("\nJoin the said two dataframes along rows:")
result_data = pd.concat([student_data1, student_data2])
print(result_data)
# Out:
# Original DataFrames:
#   student_id              name  marks
# 0         S1  Danniella Fenton    200
# 1         S2      Ryder Storey    210
# 2         S3      Bryce Jensen    190
# 3         S4         Ed Bernal    222
# 4         S5       Kwame Morin    199
# -------------------------------------
#   student_id              name  marks
# 0         S4  Scarlette Fisher    201
# 1         S5  Carla Williamson    200
# 2         S6       Dante Morse    198
# 3         S7    Kaiser William    219
# 4         S8   Madeeha Preston    201
#
# Join the said two dataframes along rows:
#   student_id              name  marks
# 0         S1  Danniella Fenton    200
# 1         S2      Ryder Storey    210
# 2         S3      Bryce Jensen    190
# 3         S4         Ed Bernal    222
# 4         S5       Kwame Morin    199
# 0         S4  Scarlette Fisher    201
# 1         S5  Carla Williamson    200
# 2         S6       Dante Morse    198
# 3         S7    Kaiser William    219
# ...

# %%
# Write a Pandas program to join the two given dataframes along columns and assign all data.

import pandas as pd

student_data1 = pd.DataFrame({
        'student_id': ['S1', 'S2', 'S3', 'S4', 'S5'],
         'name': ['Danniella Fenton', 'Ryder Storey', 'Bryce Jensen', 'Ed Bernal', 'Kwame Morin'], 
        'marks': [200, 210, 190, 222, 199]})

student_data2 = pd.DataFrame({
        'student_id': ['S4', 'S5', 'S6', 'S7', 'S8'],
        'name': ['Scarlette Fisher', 'Carla Williamson', 'Dante Morse', 'Kaiser William', 'Madeeha Preston'], 
        'marks': [201, 200, 198, 219, 201]})

print("Original DataFrames:")
print(student_data1)
print("-------------------------------------")
print(student_data2)
print("\nJoin the said two dataframes along columns:")
result_data = pd.concat([student_data1, student_data2], axis = 1)
print(result_data)
# Out:
# Original DataFrames:
#   student_id              name  marks
# 0         S1  Danniella Fenton    200
# 1         S2      Ryder Storey    210
# 2         S3      Bryce Jensen    190
# 3         S4         Ed Bernal    222
# 4         S5       Kwame Morin    199
# -------------------------------------
#   student_id              name  marks
# 0         S4  Scarlette Fisher    201
# 1         S5  Carla Williamson    200
# 2         S6       Dante Morse    198
# 3         S7    Kaiser William    219
# 4         S8   Madeeha Preston    201
#
# Join the said two dataframes along columns:
#   student_id              name  marks student_id              name  marks
# 0         S1  Danniella Fenton    200         S4  Scarlette Fisher    201
# 1         S2      Ryder Storey    210         S5  Carla Williamson    200
# 2         S3      Bryce Jensen    190         S6       Dante Morse    198
# 3         S4         Ed Bernal    222         S7    Kaiser William    219
# ...

# %%
# Write a Pandas program to append rows to an existing DataFrame and display the combined data.

import pandas as pd
student_data1 = pd.DataFrame({
        'student_id': ['S1', 'S2', 'S3', 'S4', 'S5'],
         'name': ['Danniella Fenton', 'Ryder Storey', 'Bryce Jensen', 'Ed Bernal', 'Kwame Morin'], 
        'marks': [200, 210, 190, 222, 199]})

s6 = pd.Series(['S6', 'Scarlette Fisher', 205], index=['student_id', 'name', 'marks'])
print("Original DataFrames:")
print(student_data1)
print("\nNew Row(s)")
print(s6)
combined_data = student_data1.append(s6, ignore_index = True)
print("\nCombined Data:")
print(combined_data)
# Out:
# Original DataFrames:
#   student_id              name  marks
# 0         S1  Danniella Fenton    200
# 1         S2      Ryder Storey    210
# 2         S3      Bryce Jensen    190
# 3         S4         Ed Bernal    222
# 4         S5       Kwame Morin    199
#
# New Row(s)
# student_id                  S6
# name          Scarlette Fisher
# marks                      205
# dtype: object
#
# Combined Data:
#   student_id              name  marks
# 0         S1  Danniella Fenton    200
# 1         S2      Ryder Storey    210
# 2         S3      Bryce Jensen    190
# 3         S4         Ed Bernal    222
# 4         S5       Kwame Morin    199
# 5         S6  Scarlette Fisher    205
# C:\Users\Tarunim Sharma\AppData\Local\Temp\ipykernel_3304\2310840235.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = student_data1.append(s6, ignore_index = True)

# %%
# Write a Pandas program to join the two given dataframes along rows and merge with another dataframe along the common column id.


import pandas as pd
student_data1 = pd.DataFrame({
        'student_id': ['S1', 'S2', 'S3', 'S4', 'S5'],
         'name': ['Danniella Fenton', 'Ryder Storey', 'Bryce Jensen', 'Ed Bernal', 'Kwame Morin'], 
        'marks': [200, 210, 190, 222, 199]})

student_data2 = pd.DataFrame({
        'student_id': ['S4', 'S5', 'S6', 'S7', 'S8'],
        'name': ['Scarlette Fisher', 'Carla Williamson', 'Dante Morse', 'Kaiser William', 'Madeeha Preston'], 
        'marks': [201, 200, 198, 219, 201]})

exam_data = pd.DataFrame({
        'student_id': ['S1', 'S2', 'S3', 'S4', 'S5', 'S7', 'S8', 'S9', 'S10', 'S11', 'S12', 'S13'],
        'exam_id': [23, 45, 12, 67, 21, 55, 33, 14, 56, 83, 88, 12]})

print("Original DataFrames:")
print(student_data1)
print(student_data2)
print(exam_data)

print("\nJoin first two said dataframes along rows:")
result_data = pd.concat([student_data1, student_data2])
print(result_data)

print("\nNow join the said result_data and df_exam_data along student_id:")
final_merged_data = pd.merge(result_data, exam_data, on='student_id')
print(final_merged_data)
# Out:
# Original DataFrames:
#   student_id              name  marks
# 0         S1  Danniella Fenton    200
# 1         S2      Ryder Storey    210
# 2         S3      Bryce Jensen    190
# 3         S4         Ed Bernal    222
# 4         S5       Kwame Morin    199
#   student_id              name  marks
# 0         S4  Scarlette Fisher    201
# 1         S5  Carla Williamson    200
# 2         S6       Dante Morse    198
# 3         S7    Kaiser William    219
# 4         S8   Madeeha Preston    201
#    student_id  exam_id
# 0          S1       23
# 1          S2       45
# 2          S3       12
# 3          S4       67
# 4          S5       21
# 5          S7       55
# 6          S8       33
# 7          S9       14
# 8         S10       56
# 9         S11       83
# 10        S12       88
# 11        S13       12
#
# Join first two said dataframes along rows:
#   student_id              name  marks
# 0         S1  Danniella Fenton    200
# 1         S2      Ryder Storey    210
# ...
